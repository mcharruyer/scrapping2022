# %%
import pandas as pd

# préciser le chemin du fichier à lire
cheminDuFichierCSV = "./../data/dictionary/1757_Buchanan-J.csv" 
cheminDuFichierCSV2 = "./../data/dictionary/Buchanan_PronChar_counts.csv"
cheminDuFichierCSV3 = "./../data/dataframe/BigiRichSample.csv" 


# demander à pandas de lire le fichier et garder ce tableau accessible dans une variable
dfDicoBuch = pd.read_csv(cheminDuFichierCSV2, delimiter=";", encoding="utf8")
Buch = pd.read_csv(cheminDuFichierCSV, delimiter=";", encoding="utf8")
Bigi = pd.read_csv(cheminDuFichierCSV3, delimiter=";", encoding="utf8")

# afficher à l'écran un échantillon du tableau
Bigi
# Out:
#                   hwd        pronSampa       ipa
# 0                   a                @         ə
# 1                a(2)               eI         ?
# 2             a'ready      @ r\ E d i:    əɹɛdiː
# 3                 a's             eI z        ?z
# 4                  a.               eI         ?
# ...               ...              ...       ...
# 131098  zyuganov's(3)  z u g A n A v z  zugɑnɑvz
# 131099  zyuganov's(4)  z u g A n A f s  zugɑnɑfs
# 131100        zywicki     z i w I k i:   ziwɪkiː
# 131101           zzzz           z i: z      ziːz
# 131102        zzzz(2)              z z        zz
#
# [131103 rows x 3 columns]

# %%
dfDicoBuch
# Out:
#    char    occ graph
# 0     a   3207     a
# 1     ʹ  12725   NaN
# 2     b   2288     b
# 3     ă   4533     a
# 4     c   5500     c
# ..  ...    ...   ...
# 68    á      1     a
# 69    I      1     l
# 70    х      2     x
# 71    р      1     p
# 72    ï      1     i
#
# [73 rows x 3 columns]

# %%
def motVedette(mot):
    cheminDuFichierCSV = "./../data/dictionary/Buchanan_PronChar_counts.csv"
    pronchar = pd.read_csv(cheminDuFichierCSV, delimiter=";", encoding="utf8")
    TruePron = []
    transfo = ''
    for lettre in mot:
        if (pronchar[pronchar['char']== lettre]['graph'].isnull().values[0]):
            transfo = ''
        else: transfo = pronchar[pronchar['char']== lettre]['graph'].values[0]
        TruePron.append(transfo)
    TruePron = ''.join(TruePron)
    return TruePron

# %%
motVedette("ăbăʹft")
# Out:
# 'abaft'

# %%
Buch['motVedette'] = Buch.apply(lambda x: motVedette(x['pron']),1)

# %%
Buch
# Out:
#        nbSyll        pron origin warning remarques POS  lineId  pageId  \
# 0           3     aʹbăcus    NaN     NaN       NaN  n.     2.0      19
# 1           2      ăbăʹft    NaN     NaN       NaN  p.     3.0      19
# 2           3  ăbaiʹſănce     F.     NaN       NaN  n.     4.0      19
# 3           3    ābăʹndon     F.     NaN       NaN  v.     5.0      19
# 4           4  ābăʹndŏned    NaN     NaN       NaN  a.     6.0      19
# ...       ...         ...    ...     ...       ...  ..     ...     ...
# 15795       4  zōŏʹgrăphy     G.     NaN       NaN  n.    19.0     241
# 15796       4  zōŏʹphytès     G.     NaN       NaN  n.    20.0     241
# 15797       4  zōŏʹphŏric     G.     NaN       NaN  n.    21.0     241
# 15798       4  zōŏʹtŏmiſt     G.     NaN       NaN  n.    22.0     241
# 15799       3     zŏʹtĭcā     G.     NaN       NaN  n.    23.0     241
#
#       motVedette
# 0         abacus
# 1          abaft
# 2      abaisance
# 3        abandon
# 4      abandoned
# ...          ...
# 15795  zoography
# 15796  zoophytes
# 15797  zoophoric
# 15798  zootomist
# 15799     zotica
#
# [15800 rows x 9 columns]

# %%
# afficher à l'écran un échantillon du tableau
Bigi
# Out:
#                   hwd        pronSampa       ipa
# 0                   a                @         ə
# 1                a(2)               eI         ?
# 2             a'ready      @ r\ E d i:    əɹɛdiː
# 3                 a's             eI z        ?z
# 4                  a.               eI         ?
# ...               ...              ...       ...
# 131098  zyuganov's(3)  z u g A n A v z  zugɑnɑvz
# 131099  zyuganov's(4)  z u g A n A f s  zugɑnɑfs
# 131100        zywicki     z i w I k i:   ziwɪkiː
# 131101           zzzz           z i: z      ziːz
# 131102        zzzz(2)              z z        zz
#
# [131103 rows x 3 columns]

# %%
import pandas
nvDF=pandas.merge(Bigi, Buch, left_on = ['hwd'], right_on = ['motVedette'])

# %%
nvDF
# Out:
#              hwd        pronSampa       ipa  nbSyll        pron origin  \
# 0         abacus      { b @ k @ s    æbəkəs       3     aʹbăcus    NaN
# 1        abandon    @ b { n d @ n   əbændən       3    ābăʹndon     F.
# 2      abandoned  @ b { n d @ n d  əbændənd       4  ābăʹndŏned    NaN
# 3          abash          @ b { S      əbæʃ       2      ăbăʹſh     F.
# 4          abate         @ b eI t      əb?t       2      ăbāʹte     F.
# ...          ...              ...       ...     ...         ...    ...
# 10328     zenith       z i: n @ T    ziːnəθ       2     zĕʹnith    NaN
# 10329       zest          z E s t      zɛst       1        zĕſt    NaN
# 10330       zink          z I N k      zɪŋk       1        zĭnk    NaN
# 10331     zodiac    z @U 4 i: { k  zoʊɾiːæk       3     zōʹdĭac    NaN
# 10332       zone           z @U n      zoʊn       1        zōne    NaN
#
#       warning remarques POS  lineId  pageId motVedette
# 0         NaN       NaN  n.     2.0      19     abacus
# 1         NaN       NaN  v.     5.0      19    abandon
# 2         NaN       NaN  a.     6.0      19  abandoned
# 3         NaN       NaN  v.     9.0      19      abash
# 4         NaN       NaN  v.    10.0      19      abate
# ...       ...       ...  ..     ...     ...        ...
# 10328     NaN       NaN  n.    11.0     241     zenith
# 10329     NaN       NaN  n.    13.0     241       zest
# 10330     NaN       NaN  n.    14.0     241       zink
# 10331     NaN       NaN  n.    16.0     241     zodiac
# 10332     NaN       NaN  n.    18.0     241       zone
#
# [10333 rows x 12 columns]

# %%
nvDF.to_csv('./../data/dataframe/dataframe.csv', encoding='utf-8')
